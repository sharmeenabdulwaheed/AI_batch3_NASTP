# %%
#isnull(), isnull().sum(), fillna(0)
#retrieving the columns of our choice
#retriving the columns on the basis of conditions
#reading an excel file in pandas
#introduction to matplotlib for plotting

# %%
import pandas as pd

# %%
df=pd.read_csv("D:\AI course\datasets\diabetes.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\HARMAN\AppData\Local\Temp\ipykernel_15512\2334855192.py:1: SyntaxWarning: invalid escape sequence '\A'
#   df=pd.read_csv("D:\AI course\datasets\diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.fillna(0)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.dropna()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
a=5
a=a+1

# %% [markdown]
# ## saving the changes in dataset

# %%
df=df.dropna()

#1st method and not reccomended, it lead to multiple copies of same data

# %%
df.dropna(inplace= True)

# %% [markdown]
# ## working wiht student dataset and viewing data of our choice

# %%
df=pd.read_csv("D:\AI course\datasets\student_dataset.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\HARMAN\AppData\Local\Temp\ipykernel_15512\909494762.py:1: SyntaxWarning: invalid escape sequence '\A'
#   df=pd.read_csv("D:\AI course\datasets\student_dataset.csv")

# %%
df.head()
# Out:
#   StudentID      Name  Age  Gender      Grade  Attendance  FinalExamScore
# 0     S0001  Student1   25    Male  60.212228          85       78.652064
# 1     S0002  Student2   20    Male  96.532454         100       72.347071
# 2     S0003  Student3   24  Female  79.203509          35       88.799927
# 3     S0004  Student4   24    Male  65.519182          54       66.332211
# 4     S0005  Student5   17    Male  62.680631          53       43.787086

# %%
df["Age"]
# Out:
# 0      25
# 1      20
# 2      24
# 3      24
# 4      17
#        ..
# 495    16
# 496    23
# 497    17
# 498    23
# 499    19
# Name: Age, Length: 500, dtype: int64

# %%
ages=df["Age"]

# %%
type(ages)
# Out:
# pandas.core.series.Series

# %%
ages.head()
# Out:
# 0    25
# 1    20
# 2    24
# 3    24
# 4    17
# Name: Age, dtype: int64

# %%
#for i in ages:
    #print(i)

# %%
df.head()
# Out:
#   StudentID      Name  Age  Gender      Grade  Attendance  FinalExamScore
# 0     S0001  Student1   25    Male  60.212228          85       78.652064
# 1     S0002  Student2   20    Male  96.532454         100       72.347071
# 2     S0003  Student3   24  Female  79.203509          35       88.799927
# 3     S0004  Student4   24    Male  65.519182          54       66.332211
# 4     S0005  Student5   17    Male  62.680631          53       43.787086

# %%
df[["Attendance", "Grade"]]
# Out:
#      Attendance      Grade
# 0            85  60.212228
# 1           100  96.532454
# 2            35  79.203509
# 3            54  65.519182
# 4            53  62.680631
# ..          ...        ...
# 495          10  73.928348
# 496          36  63.353273
# 497          11  78.387603
# 498          85  95.011317
# 499          56  90.531636
#
# [500 rows x 2 columns]

# %% [markdown]
# ## retrive the data of passed student using conditions

# %%
df["Grade"]>=40
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 495    True
# 496    True
# 497    True
# 498    True
# 499    True
# Name: Grade, Length: 500, dtype: bool

# %%
df[df["Grade"]>=40]
# Out:
#     StudentID        Name  Age  Gender      Grade  Attendance  FinalExamScore
# 0       S0001    Student1   25    Male  60.212228          85       78.652064
# 1       S0002    Student2   20    Male  96.532454         100       72.347071
# 2       S0003    Student3   24  Female  79.203509          35       88.799927
# 3       S0004    Student4   24    Male  65.519182          54       66.332211
# 4       S0005    Student5   17    Male  62.680631          53       43.787086
# ..        ...         ...  ...     ...        ...         ...             ...
# 495     S0496  Student496   16  Female  73.928348          10       63.297157
# 496     S0497  Student497   23    Male  63.353273          36       66.540411
# 497     S0498  Student498   17  Female  78.387603          11       83.505418
# 498     S0499  Student499   23    Male  95.011317          85       54.545547
# 499     S0500  Student500   19    Male  90.531636          56       60.780361
#
# [500 rows x 7 columns]

# %%
pass_stds= df[df["Grade"]>=40]

# %%
pass_stds.head()
# Out:
#   StudentID      Name  Age  Gender      Grade  Attendance  FinalExamScore
# 0     S0001  Student1   25    Male  60.212228          85       78.652064
# 1     S0002  Student2   20    Male  96.532454         100       72.347071
# 2     S0003  Student3   24  Female  79.203509          35       88.799927
# 3     S0004  Student4   24    Male  65.519182          54       66.332211
# 4     S0005  Student5   17    Male  62.680631          53       43.787086

# %%
## retrieving the students having short attendance

# %%
df["Attendance"]<50
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 495     True
# 496     True
# 497     True
# 498    False
# 499    False
# Name: Attendance, Length: 500, dtype: bool

# %%
df[df["Attendance"]<50]
# Out:
#     StudentID        Name  Age  Gender      Grade  Attendance  FinalExamScore
# 2       S0003    Student3   24  Female  79.203509          35       88.799927
# 6       S0007    Student7   18  Female  86.301672           9       72.293310
# 7       S0008    Student8   17    Male  73.345534          11       90.620405
# 11      S0012   Student12   21    Male  66.065837          26       80.930110
# 12      S0013   Student13   16  Female  74.296442           8       72.603368
# ..        ...         ...  ...     ...        ...         ...             ...
# 492     S0493  Student493   18    Male  77.838279           3       65.035916
# 494     S0495  Student495   22  Female  62.623730           1       77.762109
# 495     S0496  Student496   16  Female  73.928348          10       63.297157
# 496     S0497  Student497   23    Male  63.353273          36       66.540411
# 497     S0498  Student498   17  Female  78.387603          11       83.505418
#
# [236 rows x 7 columns]

# %%
drop_stds=df[df["Attendance"]<50]

# %%
drop_stds.head(3)
# Out:
#   StudentID      Name  Age  Gender      Grade  Attendance  FinalExamScore
# 2     S0003  Student3   24  Female  79.203509          35       88.799927
# 6     S0007  Student7   18  Female  86.301672           9       72.293310
# 7     S0008  Student8   17    Male  73.345534          11       90.620405

# %%
drop_stds.head()
# Out:
#    StudentID       Name  Age  Gender      Grade  Attendance  FinalExamScore
# 2      S0003   Student3   24  Female  79.203509          35       88.799927
# 6      S0007   Student7   18  Female  86.301672           9       72.293310
# 7      S0008   Student8   17    Male  73.345534          11       90.620405
# 11     S0012  Student12   21    Male  66.065837          26       80.930110
# 12     S0013  Student13   16  Female  74.296442           8       72.603368

# %%
import matplotlib.pyplot as plt

# %%
names=["Ali", "Shahzaib", "Ahmed", "Musa"]
marks=[58, 78, 19, 9]

# %%
plt.bar(names, marks)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.scatter(names, marks)

# %%
plt.plot(names, marks)

# %%
plt.barh(names, marks, color="green")
# Out:
# <BarContainer object of 4 artists>

# %%
plt.plot(names, marks, marker="s", linestyle="--")
plt.title("Line plot for marks of Grade-9")
plt.xlabel("Names of students")
plt.ylabel("Marks of students")

plt.show()

# %% [markdown]
# ## complete assignment

# %%
df= pd.read_excel("D:/AI course/datasets/test.xlsx")

# %%
df.head()
# Out:
#        Name   Age  Marks
# 0       ali  12.0   40.0
# 1     ahmed  15.0   90.0
# 2  Abubakar  18.0    NaN
# 3   Malaika  23.0   45.0
# 4     Eisha  34.0   29.0

# %%
df.dropna(inplace=True)

# %%
plt.bar(df["Name"], df["Marks"])
# Out:
# <BarContainer object of 11 artists>
